# %% [markdown]
# ## Project description
#     We are trying to find which factors influence someone not leaving telecom (not having an end date).
#
#     You have access to behavior data about users based on their contract, personal, internet and phone data. For this classification task, you need to develop a model that will predict whether or not a user will have an end date.
#
#     Develop a model with the highest possible accuracy. Check the accuracy using the test dataset. In this project, the threshold for accuracy is 0.75, but an 0.88 or greater is best. Pick the Best Model based on the AUC-ROC score.
# ## Project Instructions
# ### Step 1. Open the data file and study the general information
# #### File path:
#     /final_provider/contract.csv
#     /final_provider/internet.csv
#     /final_provider/personal.csv
#     /final_provider/phone.csv
# ### Step 2. Prepare the data
#     Convert the data to the necessary types
#     Find and eliminate errors in the data
#     Explain what errors you found and how you removed them.
#     Make sure the data is balanced.
#     Remember to include customers who have only picked only plans (Don't delete customers NaNs in other plans, just encode a column for them
#     Encode the data.
#     Careful with data leakage, make sure to not include features that may be collinear (i.e if using one-hot encoding for categorical variables, drop one of the columns) or reference the target variable in some way (see topic on data leakage)
#
# ### Step 3. Analyze the data
#     Describe the customers' behavior.
#     Calculate the mean, variance, and standard deviation.
#     Plot histograms.
#     Describe the distributions.
#     If possible, explain the correlation between certain features.
#
# ### Step 4. Split the source data into a training set, a validation set, and a test set.
#
# ### Step 5. Investigate the quality of different models by changing hyperparameters on the validation set  preferably using: Dummy Model, Logistic Regression, Support Vector Machine, Random Forest, and Neural Network. Briefly describe the findings of the study
#
# ### Step 6. Check the quality of the model using the test set. Incase of an class imbalance in the data, make sure you upsample or SMOTE
#
# ### Step 7. Additional task: sanity check the model. This data is more complex than what you’re used to working with, so it's not an easy task. We'll take a closer look at it later.
#
# ### Step 8. Examine the balance of classes. Train the model without taking into account the imbalance. Briefly describe your findings.
#
# ### Step 9. Improve the quality of the model. Make sure you use at least two approaches to fixing class imbalance. Use the test set to pick the best parameters. Train different models on training and validation sets. Find the best one. Briefly describe your findings.
#
# ### Step 10.  Perform the final testing.
#
# ### Step 11. Report your conclusion.
#
# ## Data description
# #### The contract table (data on contracts):
#     customerID - unique user identifier
#     BeginDate - beginning date of user using service
#     EndDate - end date of user using service
#     Type - type of service how often payments are made.
#     PaperlessBilling - monthly statement recieved with or without paper bills.
#     PaymentMethod - prefered method of payment
#     MonthlyCharges - avg monthly charges
#     TotalCharges - total charges
# #### The internet table (data on internet service plans):
#     customerID - unique user identifier
#     InternetService - internet service type
#     OnlineSecurity - whether or not their internet service is protected
#     OnlineBackup - whether or not their internet service is backed up/saved
#     DeviceProtection - screen repair, battery replacement & same day replacement of your damaged, lost & stolen item
#     TechSupport - online or phone support for billing, plans and tech issues
#     StreamingTV - including a streaming service for live tv
#     StreamingMovies - including a streaming service for movies
# #### The personal table (data on personal info):
#     customerID - unique user identifier
#     gender - user gender
#     SeniorCitizen - if the user is a senior citizen or not
#     Partner - if the user has a partner
#     Dependents - if the user has dependents
# #### The phone table(data on phone plan):
#     customerID
#     MultipleLines
